# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from cassandrautils import *

# %%
weather = getWeatherDF()

weather['forecast_timestamp'] = pd.to_datetime(weather['forecastdate'], format="%d-%m-%Y %H:%M")
print("Weather from ", weather['forecast_timestamp'].min(), " To ", weather['forecast_timestamp'].max())
# Out:
# Weather from  2023-12-08 06:50:08  To  2023-12-08 08:31:28

# %%
weather
# Out:
#     location        forecastdate      description  feels_like  humidity  \
# 0    Chicago 2023-12-08 06:50:38        clear sky  277.700012      75.0
# 1    Chicago 2023-12-08 06:51:39        clear sky  277.700012      75.0
# 2    Chicago 2023-12-08 06:52:39        clear sky  277.700012      75.0
# 3    Chicago 2023-12-08 06:53:40        clear sky  277.700012      75.0
# 4    Chicago 2023-12-08 06:54:40        clear sky  277.700012      75.0
# ..       ...                 ...              ...         ...       ...
# 117   Dallas 2023-12-08 08:27:26  overcast clouds  290.649994      84.0
# 118   Dallas 2023-12-08 08:28:27  overcast clouds  290.700012      84.0
# 119   Dallas 2023-12-08 08:29:27  overcast clouds  290.700012      84.0
# 120   Dallas 2023-12-08 08:30:28  overcast clouds  290.700012      84.0
# 121   Dallas 2023-12-08 08:31:28  overcast clouds  290.700012      84.0
#
#      pressure     sunrise      sunset        temp    temp_max    temp_min  \
# 0      1007.0  1702040726  1702073983  281.079987  282.059998  279.869995
# 1      1007.0  1702040726  1702073983  281.079987  282.059998  279.869995
# 2      1007.0  1702040726  1702073983  281.079987  282.059998  279.869995
# 3      1007.0  1702040726  1702073983  281.079987  282.059998  279.869995
# 4      1007.0  1702040726  1702073983  281.079987  282.059998  279.869995
# ..        ...         ...         ...         ...         ...         ...
# 117    1010.0  1702041432  1702077663  290.649994  291.570007  289.339996
# 118    1011.0  1702041432  1702077663  290.700012  291.570007  289.359985
# 119    1011.0  1702041432  1702077663  290.700012  291.570007  289.359985
# 120    1011.0  1702041432  1702077663  290.700012  291.570007  289.359985
# 121    1011.0  1702041432  1702077663  290.700012  291.570007  289.359985
#
#      wind  forecast_timestamp
# 0    6.17 2023-12-08 06:50:38
# 1    6.17 2023-12-08 06:51:39
# 2    6.17 2023-12-08 06:52:39
# 3    6.17 2023-12-08 06:53:40
# 4    6.17 2023-12-08 06:54:40
# ..    ...                 ...
# 117  8.23 2023-12-08 08:27:26
# 118  8.23 2023-12-08 08:28:27
# 119  8.23 2023-12-08 08:29:27
# 120  8.23 2023-12-08 08:30:28
# 121  8.23 2023-12-08 08:31:28
#
# [122 rows x 13 columns]

# %%
faker = getFakerDF()

faker
# Out:
#                                        id                           street  \
# 0    9f3fe800-1bf7-489b-a7ff-db29ccb2078f                8192 Adam Station
# 1    d46a4636-dc9b-4d14-8f59-695e63402c5e      882 Caroline Park Suite 333
# 2    7cc96cc3-666b-4cac-8731-6eb80768a086             676 Barrett Turnpike
# 3    6bd839cc-9bbb-4c96-adcd-20d279131738    78552 Robinson Glens Apt. 841
# 4    2dedcfe5-8cad-493d-86df-6e1a4da501e4  9627 Hunter Junctions Suite 369
# ..                                    ...                              ...
# 119  b813f046-0c7c-4ed2-b5cc-303dc128881f      54796 Jennifer Rue Apt. 134
# 120  5e0dda92-2422-4a6a-92d4-bfacdd51f44a   149 Kimberly Village Suite 641
# 121  59321cde-70ad-40d1-88cb-41dcadc1640e       935 Sherry Drives Apt. 787
# 122  ec60af7b-32ad-44ab-b62b-c89b14eea200       4619 Donna Brook Suite 359
# 123  2c7acaf8-ad6b-4887-b1b7-f9a7475cd77b      6296 Perry Fields Suite 927
#
#     buildingnumber                   city  \
# 0            87307          Martinchester
# 1              345            New Crystal
# 2             2956             East Brian
# 3             5931             Adkinsbury
# 4             8145             Murphytown
# ..             ...                    ...
# 119          52383  East Catherinechester
# 120          23320              West Lisa
# 121            860             Thomasland
# 122            348         Brennanborough
# 123          26332          South Zachary
#
#                                           country country_code     latitude  \
# 0                                           Tonga           CL  -28.1149315
# 1                    Svalbard & Jan Mayen Islands           NO   -74.382143
# 2                                            Oman           MM    36.725464
# 3                                         Germany           BT   85.8596835
# 4                              Russian Federation           DM  -82.2886765
# ..                                            ...          ...          ...
# 119                                         Aruba           VN    65.114154
# 120                                        Tuvalu           VC   -1.6412535
# 121                                     Gibraltar           DM   46.2834955
# 122                                        Greece           MG   65.3615495
# 123  South Georgia and the South Sandwich Islands           SM  -42.7193115
#
#        longitude        streetname zipcode
# 0      13.346935  Collin Junctions   51654
# 1     -52.426914     Madison Cliff   98130
# 2     -58.470634     Martinez Lake   91144
# 3      45.151917      Duarte Grove   97451
# 4    -140.402839     Hayes Terrace   69394
# ..           ...               ...     ...
# 119   116.986266   Hernandez Plaza   97426
# 120   -23.750610   Johnston Shores   51869
# 121    16.207907       Moody Falls   64886
# 122   -82.611315         Ryan Rest   57064
# 123   -71.691536      Cooper Rapid   81974
#
# [124 rows x 10 columns]

# %%
iqair = getIQAirDF()

iqair['current_ts'] = pd.to_datetime(iqair['current_ts'], format="%d-%m-%Y %H:%M")
print("Air Quality from ", iqair['current_ts'].min(), " To ", iqair['current_ts'].max())
# Out:
# Air Quality from  2023-12-08 06:00:00  To  2023-12-08 08:00:00

# %%
iqair
# Out:
#                   city          current_ts country  current_pollution_aqicn  \
# 0                Homer 2023-12-08 06:00:00     USA                        2
# 1              Indiana 2023-12-08 07:00:00     USA                       10
# 2      East Longmeadow 2023-12-08 07:00:00     USA                        9
# 3              Newport 2023-12-08 06:00:00     USA                        9
# 4            June Lake 2023-12-08 08:00:00     USA                        6
# 5              Milford 2023-12-08 07:00:00     USA                       20
# 6   Cottonwood Heights 2023-12-08 07:00:00     USA                        4
# 7          Canyon Lake 2023-12-08 08:00:00     USA                        0
# 8         Chesterfield 2023-12-08 07:00:00     USA                        9
# 9             Olivette 2023-12-08 07:00:00     USA                        9
# 10            Columbus 2023-12-08 06:00:00     USA                       20
# 11            Edgemoor 2023-12-08 06:00:00     USA                       17
# 12            Coos Bay 2023-12-08 07:00:00     USA                       12
# 13             Medford 2023-12-08 07:00:00     USA                       18
# 14               Velva 2023-12-08 07:00:00     USA                       19
# 15           Indianola 2023-12-08 06:00:00     USA                       15
# 16    Washington, D.C. 2023-12-08 06:00:00     USA                       17
# 17           Baltimore 2023-12-08 07:00:00     USA                       22
# 18        Maple Valley 2023-12-08 08:00:00     USA                        0
# 19                Ames 2023-12-08 06:00:00     USA                       11
# 20            Marshall 2023-12-08 06:00:00     USA                       15
# 21             Warwick 2023-12-08 07:00:00     USA                       29
# 22         Hattiesburg 2023-12-08 06:00:00     USA                       22
# 23         Chattanooga 2023-12-08 07:00:00     USA                       16
# 24    Montville Center 2023-12-08 06:00:00     USA                       17
# 25     Chenango Bridge 2023-12-08 06:00:00     USA                       36
# 26            Rockland 2023-12-08 06:00:00     USA                       21
# 27          Montgomery 2023-12-08 07:00:00     USA                        4
# 28        West Milford 2023-12-08 07:00:00     USA                       40
# 29            Waterloo 2023-12-08 06:00:00     USA                       10
# 30               Blair 2023-12-08 07:00:00     USA                        7
#
#     current_pollution_aqius current_pollution_maincn current_pollution_mainus  \
# 0                         7                       p2                       p2
# 1                        29                       p2                       p2
# 2                        25                       p2                       p2
# 3                        25                       p2                       p2
# 4                        17                       p2                       p2
# 5                        55                       p2                       p2
# 6                        12                       p2                       p2
# 7                         0                       p2                       p2
# 8                        27                       p2                       p2
# 9                        25                       p2                       p2
# 10                       54                       p2                       p2
# 11                       50                       p2                       p2
# 12                       35                       p2                       p2
# 13                       51                       p2                       p2
# 14                       53                       p2                       p2
# 15                       42                       p2                       p2
# 16                       48                       p2                       p2
# 17                       58                       p2                       p2
# 18                        1                       p2                       p2
# 19                       31                       p2                       p2
# 20                       43                       p2                       p2
# 21                       68                       p2                       p2
# 22                       58                       p2                       p2
# 23                       46                       p2                       p2
# 24                       50                       p2                       p2
# 25                       78                       p2                       p2
# 26                       56                       p2                       p2
# 27                       11                       p2                       p2
# 28                       84                       p2                       p2
# 29                       30                       p2                       p2
# 30                       21                       p2                       p2
#
#     current_weather_hu current_weather_ic  current_weather_pr  \
# 0                   51                02n                 999
# 1                   93                04n                1017
# 2                   83                04n                1017
# 3                   85                01n                1017
# 4                   55                01n                1026
# 5                   91                04n                1009
# 6                   62                04n                1011
# 7                   88                04n                1011
# 8                   60                04n                1009
# 9                   61                04n                1009
# 10                  75                01n                1019
# 11                  79                01n                1018
# 12                  93                04n                1026
# 13                  91                01n                1000
# 14                  88                04n                 992
# 15                  70                04n                1017
# 16                  76                01n                1018
# 17                  86                01n                1020
# 18                  90                04n                1019
# 19                  82                01n                 991
# 20                  65                01n                 993
# 21                  89                04n                1019
# 22                  93                01n                1019
# 23                  69                01n                1021
# 24                  77                04n                1018
# 25                  90                04n                 996
# 26                  87                01n                1016
# 27                  67                04n                1020
# 28                  87                04n                1018
# 29                  81                04n                 999
# 30                  65                01n                1000
#
#     current_weather_tp  current_weather_wd  current_weather_ws    latitude  \
# 0                   -2                 240               12.52 -151.549400
# 1                    0                   0                0.00  -79.152530
# 2                   -1                   9                0.45  -72.512590
# 3                   -2                   0                0.00  -71.312830
# 4                   -8                 241                3.17 -119.075420
# 5                    2                 148                1.34  -83.730288
# 6                    1                  88                2.24 -111.794864
# 7                   18                 193                2.68  -98.262510
# 8                   10                 190                5.14  -90.522132
# 9                   10                 190                5.14  -90.375950
# 10                   5                 150                4.12  -88.427260
# 11                   0                 264                0.45  -75.499640
# 12                   6                 140                3.60 -124.217890
# 13                   1                 135                4.60  -90.600000
# 14                   3                 301                7.95 -100.929320
# 15                   8                 185                5.13  -90.655090
# 16                   2                   0                0.00  -76.958089
# 17                   1                   0                0.00  -76.296700
# 18                   4                 288                0.89 -122.046410
# 19                   8                 210                5.66  -93.619940
# 20                   6                 240                9.26  -95.835000
# 21                   0                 271                1.04  -74.359880
# 22                   5                   0                0.00  -89.287498
# 23                   5                 140                1.54  -85.293100
# 24                  -1                  10                2.06  -72.151190
# 25                   1                 250                3.09  -75.862420
# 26                  -9                 290                1.54  -69.108930
# 27                   1                 158                2.18  -81.328450
# 28                   0                 287                1.16  -74.434970
# 29                   9                 180                4.63  -92.315804
# 30                   7                   0                0.00  -96.125020
#
#     longitude                 state
# 0   59.642500                Alaska
# 1   40.621460          Pennsylvania
# 2   42.064540         Massachusetts
# 3   41.490100          Rhode Island
# 4   37.779650            California
# 5   42.635482              Michigan
# 6   40.611324                  Utah
# 7   29.875220                 Texas
# 8   38.658071              Missouri
# 9   38.665330              Missouri
# 10  33.495670           Mississippi
# 11  39.750110              Delaware
# 12  43.366500                Oregon
# 13  45.203900             Wisconsin
# 14  48.056120          North Dakota
# 15  33.450950           Mississippi
# 16  38.895683  District of Columbia
# 17  39.410000              Maryland
# 18  47.392720            Washington
# 19  42.034710                  Iowa
# 20  44.457200             Minnesota
# 21  41.256480              New York
# 22  31.322779           Mississippi
# 23  35.050800             Tennessee
# 24  41.478990           Connecticut
# 25  42.166740              New York
# 26  44.103690                 Maine
# 27  38.180380         West Virginia
# 28  41.070592            New Jersey
# 29  42.501400                  Iowa
# 30  41.544440              Nebraska

# %%
#ns10min = 30*60*1000000000   # 30 minutes in nanoseconds 
#tweets['Tweet timestamp 10mins'] = pd.to_datetime(((tweets['Tweet timestamp'].astype(np.int64) // ns10min + 1 ) * ns10min))
#tweets['Tweet timestamp 10mins'] = pd.to_datetime(tweets['Tweet timestamp 10mins'], format="%d-%m-%Y %H:%M")

# %%
df_filtered_chicago = weather[weather['location'] == 'Chicago']
df_filtered_dallas = weather[weather['location'] == 'Dallas']

# %%
sns.lineplot(data=weather, x="forecast_timestamp", y="temp", hue="location")
plt.xlabel('Timestamp')
plt.ylabel('Temperature (Kelvin)')
plt.title('Temperature over time in Chicago and Dallas')
# Out:
# Text(0.5, 1.0, 'Temperature over time in Chicago and Dallas')

# %%
sns.lineplot(data=weather, x="forecast_timestamp", y="wind", hue='location')
plt.xlabel('Timestamp')
plt.ylabel('wind')
plt.title('Wind over time in Chicago and Dallas')
# Out:
# Text(0.5, 1.0, 'Wind over time in Chicago and Dallas')

# %%
sns.lineplot(data=weather, x="forecast_timestamp", y="feels_like", hue='location')
plt.xlabel('Timestamp')
plt.ylabel('feels_like (Kelvin)')
plt.title('\'feels like\' temperature over time in Chicago and Dallas')
# Out:
# Text(0.5, 1.0, "'feels like' temperature over time in Chicago and Dallas")

# %%
sns.lineplot(data=iqair, x="current_ts", y="current_weather_tp")
plt.xlabel('Timestamp')
plt.ylabel('Temperature (Celsius)')
plt.title('Temperature over time in USA')
# Out:
# Text(0.5, 1.0, 'Temperature over time in USA')

# %%
sns.lineplot(data=iqair, x="current_ts", y="current_weather_pr")
plt.xlabel('Timestamp')
plt.ylabel('Atmospheric Pressure (hPa)')
plt.title('Atmospheric Pressure over time in USA')
# Out:
# Text(0.5, 1.0, 'Atmospheric Pressure over time in USA')

# %%
sns.lineplot(data=iqair, x="current_ts", y="current_pollution_aqius")
plt.xlabel('Timestamp')
plt.ylabel('AQI')
plt.title('AQI (Air Quality Index) value based on US EPA standard')
# Out:
# Text(0.5, 1.0, 'AQI (Air Quality Index) value based on US EPA standard')
